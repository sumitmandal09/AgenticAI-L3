# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gpt-oss:120b-cloud")

# %%
response = llm.invoke("WHAT IS THE CURRENT WEATHER IN jAIPUR CITY?")

# %%
print(response.content)
# Out:
# I’m not able to fetch live data, so I can’t give you the exact current weather in Jaipur right now. For the most up‑to‑date conditions (temperature, chance of rain, humidity, wind, etc.), you can check a reliable weather source such as:
#
# - **Weather.com** – search “Jaipur, India”
# - **AccuWeather** – search “Jaipur, India”
# - **Google** – just type “Jaipur weather” in the search bar
# - **Your phone’s weather app** (most smartphones have a built‑in widget)
#
# These services update every few minutes and will give you the latest temperature, forecasts, and any weather alerts for Jaipur. If you need help interpreting the forecast or planning activities around the weather, feel free to ask!
