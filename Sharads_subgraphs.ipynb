# %% [markdown]
# # LangGraph Subgraphs — Different State Schemas
#
# This notebook demonstrates the **different-schema** pattern for LangGraph
# subgraphs: the subgraph (`SubState`) has its own state shape, separate from
# the parent graph's (`ParentState`). Because the schemas differ, the parent
# graph can't add the compiled subgraph directly as a node — instead a small
# wrapper node (`translate_answer`) calls `subgraph.invoke(...)`, translating
# between the two state shapes by hand.
#
# Flow: `question` → generate an English answer (parent) → invoke the subgraph
# to translate it to Hindi (subgraph has its own `input_text`/`translated_text`
# state).
#
# **Models (local, via [Ollama](https://ollama.com), no API key required):**
# - `llama3.2:3b` — small, fast local model used to generate the initial English answer.
# - `gpt-oss:120b-cloud` — larger model (run through Ollama's cloud inference) used for the Hindi translation, where quality matters more.
#
# **Prerequisites:**
# 1. [Ollama](https://ollama.com) installed and running.
# 2. Models pulled/available: `ollama pull llama3.2:3b` and `ollama pull gpt-oss:120b-cloud` (the `-cloud` model needs `ollama signin` once, since it runs on Ollama's cloud rather than your machine).
# 3. Run this notebook using the project's `.venv` kernel (it already has `langchain-ollama`, `langgraph`, etc. installed).

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama

# %%
class SubState(TypedDict):

    input_text: str
    translated_text: str

# %% [markdown]
# **Subgraph's own state** — deliberately different from `ParentState` (below):
# it only knows about `input_text` / `translated_text`, not `question` or
# `answer_eng`.

# %%
subgraph_llm = ChatOllama(model='gpt-oss:120b-cloud')

# %% [markdown]
# The subgraph uses the bigger `gpt-oss:120b-cloud` model, since translation
# quality benefits from a larger model.

# %%
def translate_text(state: SubState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["input_text"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'translated_text': translated_text}

# %% [markdown]
# **Subgraph node** — translates `input_text` into `translated_text`.

# %%
subgraph_builder = StateGraph(SubState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %% [markdown]
# **Build & compile the subgraph** on its own `SubState` — a single
# `translate_text` node from `START` to `END`.

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %% [markdown]
# **Parent state** — separate schema from the subgraph's `SubState`, which is
# exactly why the parent graph will need a wrapper node to bridge between them.

# %%
#parent_llm = ChatOllama(model='llama3.2:3b')
parent_llm = ChatOllama(model='gpt-oss:120b-cloud')

# %% [markdown]
# The parent graph uses the small, fast `llama3.2:3b` model to draft the
# English answer.

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %% [markdown]
# **Parent node** — generates the English answer for the incoming `question`.

# %%
def translate_answer(state: ParentState):

    # call the subgraph
    result = subgraph.invoke({'input_text': state['answer_eng']})

    return {'answer_hin': result['translated_text']}

# %% [markdown]
# **Wrapper node** — this is the bridge between the two schemas: it builds the
# subgraph's `SubState` input from `ParentState`, invokes the subgraph, then
# maps the subgraph's output back into `ParentState`.

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", translate_answer)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %% [markdown]
# **Build the parent graph.** Unlike the shared-schema notebook, `translate` here
# is the plain Python wrapper function (`translate_answer`), not the compiled
# subgraph itself.

# %%
graph = parent_builder.compile()

graph

# %% [markdown]
# Compile the parent graph and (in a notebook with Mermaid/graphviz support)
# render it.

# %%
graph.invoke({'question': 'Why Katappa kills Bahubali?'})
# Out:
# {'question': 'Why Katappa kills Bahubali?',
#  'answer_eng': '**Spoiler warning – the answer contains major plot points from *Baahubali: The Beginning* and *Baahubali: The Conclusion*.**  \n\nIn the *Baahubali* saga, Kattappa (often spelled “Katappa”) is a **devout, lifelong servant of the throne of Mahishmati**, bound by an oath that obliges him to obey the reigning monarch no matter what. This oath is the central reason why he ends up killing Amarendra\u202fBaahubali, even though he loves and respects the hero.\n\n### The chain of events that lead to Kattappa’s act\n\n| Step | What happens | Why it matters to Kattappa |\n|------|--------------|----------------------------|\n| 1. **Baahulali’s rise** | Amarendra\u202fBaahubali becomes the beloved prince and later the king of Mahishmati, winning the love of the people, the royal family, and Kattappa himself. | Kattappa sees Baahubali as a worthy ruler and a friend. |\n| 2. **Political intrigue** | Bhallaladeva, Baahubali’s cousin, and his mother, Queen Sivagami’s sister, conspire to dethrone Baahubali. They spread rumors that Baahubali is plotting to kill the queen and take the throne. | Kattappa’s loyalty is to the *queen* (Sivagami) and the *crown*, not to any individual. |\n| 3. **Queen Sivagami issues an order** | Believing the false accusations (or being manipulated), Queen Sivagami issues a secret command: “The man who sits on the throne must be killed,” pointing to Baahubali. She gives this order through an emissary, and Kattappa is the one who receives it. | Kattappa’s oath says he must obey any direct order from the queen, even if it means killing the king. |\n| 4. **Kattappa’s dilemma** | Kattappa is torn between his personal affection for Baahubali and his unbreakable oath to the queen. He knows that disobeying a royal command would be considered treason, leading to his own death and dishonor. | The oath is absolute; historically, Kattappa’s lineage has always followed it, even at the cost of their own lives. |\n| 5. **The act** | Kattappa confronts Baahubali on the cliffs of Kuntala and, with a heavy heart, stabs him, fulfilling the queen’s command. | He does it **not because he wants Baahubali dead**, but because his sense of duty and the fear of catastrophic consequences for disobedience leave him no other choice. |\n\n### Key reasons Kattappa kills Baahubali\n\n1. **Unquestioned loyalty to the throne**  \n   - Kattappa’s entire identity is built around the principle: *“One must obey the command of the ruling monarch, no matter the personal cost.”* This cultural code is repeatedly emphasized in the films.\n\n2. **A direct royal order**  \n   - The queen’s command was explicit: “The man on the throne must die.” Kattappa receives this as a direct order, not a suggestion.\n\n3. **Fear of treason and its fallout**  \n   - Disobeying a queen’s command would be considered the highest betrayal. For a man who has served generations of rulers, such treason would mean the end of his family line, loss of honor, and potentially the collapse of the kingdom’s stability.\n\n4. **Manipulation and misinformation**  \n   - The order was based on false accusations spread by Bhallaladeva’s faction. Kattappa had no way of confirming the truth in the heat of the moment, so he acted on the *information he trusted*—the queen’s word.\n\n5. **Tragic sacrifice**  \n   - The scene is purposefully written as a tragic sacrifice: Kattappa does what he believes is his *duty*, knowing that it will shatter his own heart. The film’s tagline “The reason behind Kattappa’s betrayal is a love so deep it becomes a curse” captures this duality.\n\n### In short\n\nKattappa kills Baahubali because **his absolute oath to obey any command from the ruling queen overrides his personal love and loyalty to Baahubali**. He is forced into a tragic position where the only way to stay true to his duty—and avoid being labeled a traitor—is to carry out the order he believes is legitimate, even though it means murdering the man he considers a brother. This confli ...
| कत्तप्पा कूँतला की चट्टानों पर बाहुबली का सामना करते हैं और भारी मन से उसे छुरा मारते हैं, रानी के आदेश को पूरा करते हैं। | वह **बाहुबली को मारना नहीं चाहते**, बल्कि उनका कर्तव्यभाव और आज्ञा का उल्लंघन करने के विनाशकारी परिणामों का भय उन्हें कोई विकल्प नहीं छोड़ता। |\n\n### कत्तप्पा बाहुबली को मारते हैं, इसके मुख्य कारण\n\n1. **सिंहासन के प्रति अविचल निष्ठा**  \n   - कत्तप्पा की पूरी पहचान इस सिद्धांत पर बनी है: *“शासन‑धारी की आज्ञा का पालन चाहे व्यक्तिगत कीमत कुछ भी हो, किया जाना चाहिए।”* यह सांस्कृतिक कोड फिल्म में कई बार दोहराया गया है।\n\n2. **सीधा शाही आदेश**  \n   - रानी का आदेश स्पष्ट था: “सिंहासन पर बैठा आदमी मरना चाहिए।” कत्तप्पा इसे एक सीधा आदेश मानते हैं, न कि सुझाव।\n\n3. **गद्दारी और उसके परिणामों का भय**  \n   - रानी के आदेश का उल्लंघन सबसे बड़ी गद्दारी माना जाएगा। कई शासकों की सेवा करने वाले व्यक्ति के लिए ऐसी गद्दारी का अर्थ होगा परिवार का नाश, सम्मान का ह्रास और संभवतः राज्य की स्थिरता का टूटना।\n\n4. **धोखा और गलत जानकारी**  \n   - यह आदेश भल्लालदेव के समूह द्वारा फैलाए गए झूठे आरोपों पर आधारित था। कत्तप्पा के पास उस क्षण में सत्य की पुष्टि करने का साधन नहीं था, इसलिए उन्होंने *जिस सूचना पर भरोसा किया था*—रानी के शब्द—पर कार्रवाई की।\n\n5. **त्रासदीपूर्ण बलिदान**  \n   - दृश्य को जान‑बूझकर एक त्रासदी के रूप में लिखा गया है: कत्तप्पा वह करते हैं जो वह अपना *कर्तव्य* मानते हैं, यह जानते हुए कि इससे उनका अपना दिल टूट जाएगा। फिल्म की टैगलाइन “कत्तप्पा के विश्वासघात का कारण इतना गहरा प्रेम है जो अभिशाप बन जाता है” इस दोहरी भावना को दर्शाती है।\n\n### संक्षेप में\n\nकत्तप्पा बाहुबली को इसलिए मारते हैं क्योंकि **रानी के किसी भी आदेश का पालन करने की उनकी अटल शपथ व्यक्तिगत प्रेम और बाहुबली के प्रति निष्ठा से ऊपर है**। वे एक ऐसी त्रासदीपूर्ण स्थिति में दबे होते हैं जहाँ कर्तव्य के साथ सच्चे रहने और ख़ुद को गद्दार कहे जाने से बचने का एकमात्र रास्ता वह आदेश पूरा करना है, भले ही इसका मतलब है वह व्यक्ति मारना जिसे वह भाई मानते हैं। व्यक्तिगत स्नेह और संस्थागत निष्ठा के बीच यह टकराव ही *बाहुबली* कथा की मुख्य त्रासदी को उत्पन्न करता है।'}

# %% [markdown]
# Run the whole graph end-to-end: ask a question in English, get back both the
# English answer and its Hindi translation.
